# %%
import cv2
import os
import numpy
import numpy as np
import sys
import argparse
import logging
import pathlib
import json
import threading
import glob
import shutil
from matplotlib import pyplot as plt

# %%
def fix_image_size_(image: numpy.array, expected_pixels: float = 2E6):
    ratio = expected_pixels / (image.shape[0] * image.shape[1])
    return cv2.resize(image, (0, 0), fx=ratio, fy=ratio)


def estimate_blur(image: numpy.array, threshold: int = 100):
    if image.ndim == 3:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    blur_map = cv2.Laplacian(image, cv2.CV_64F)
    score = numpy.var(blur_map)
    return blur_map, score, bool(score < threshold)


def pretty_blur_map(blur_map: numpy.array, sigma: int = 5, min_abs: float = 0.5):
    abs_image = numpy.abs(blur_map).astype(numpy.float32)
    abs_image[abs_image < min_abs] = min_abs

    abs_image = numpy.log(abs_image)
    cv2.blur(abs_image, (sigma, sigma))
    return cv2.medianBlur(abs_image, sigma)
def mask_invalid_pixel(img,roi):
    x,y,w,h=roi
    img[:y]=0
    img[:,:x]=0
    img[y+h:]=0
    img[:,x+w:]=0
    return img

# %%
def find_images(image_paths, img_extensions=['.jpg', '.png', '.jpeg']):
    img_extensions += [i.upper() for i in img_extensions]

    for path in image_paths:
        path = pathlib.Path(path)

        if path.is_file():
            if path.suffix not in img_extensions:
                logging.info(f'{path.suffix} is not an image extension! skipping {path}')
                continue
            else:
                yield path

        if path.is_dir():
            for img_ext in img_extensions:
                yield from path.rglob(f'*{img_ext}')

# %%
def get_result(args,image_path,fix_size,results):
    image = cv2.imread(str(image_path))
    if image is None:
        logging.warning(f'warning! failed to read image from {image_path}; skipping!')
        return 
    #logging.info(f'processing {image_path}')

    if fix_size:
        image = fix_image_size_(image)
    else:
        logging.warning('not normalizing image size for consistent scoring!')

    blur_map, score, blurry = estimate_blur(image, threshold=args.threshold)

    #logging.info(f'image_path: {image_path} score: {score} blurry: {blurry}')
    results.append({'input_path': str(image_path), 'score': score, 'blurry': blurry})

# %%
# with np.load("/home/xiangfeng/NAS/d2ft/playground/230406_motion_database/calib.npz") as camdata:
#     mtx = camdata['mtx']
#     dist = camdata['dist']
#     W = camdata['W']
#     H = camdata['H']
#     print(mtx)
mtx=np.array([ 1.6281047626587153e+03, 0., 5.4239393119148224e+02, 0.,1.6291122927710098e+03, 9.6233223381000607e+02, 0., 0., 1.  ]).reshape((3,3))
dist=np.array([2.7659540439639703e-02, 5.3863103363621501e-01,3.9710184124524791e-03, 8.2175531244021820e-04,-2.3807468377690459e+00]).reshape((5,1))
W=1080
H=1920

# %%
def parse_args():
    parser = argparse.ArgumentParser(description='run blur detection on a single image')
    parser.add_argument('--images_root', type=str, default=r"D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34")
    parser.add_argument('--threshold', type=float, default=100)
    parser.add_argument('--variable-size', action='store_true')
    parser.add_argument('--verbose', action='store_true')
    args, unknown = parser.parse_known_args([])
    args.output_dir = f"{args.images_root}/selected"
    return args

args = parse_args()
fix_size = not args.variable_size
level = logging.DEBUG if args.verbose else logging.INFO
imgpaths = sorted(glob.glob(os.path.join(args.images_root,"*.png")))
print(len(imgpaths))
# Out:
# 1199

# %%
results = []
thread_collector = []
max_thread_num = 60
for index, image_path in enumerate(imgpaths):
    print(f"\r{index}/{len(imgpaths)}", end=" ")
    tmp_thread = threading.Thread(target=get_result, args=(args, image_path, fix_size, results))
    tmp_thread.start()
    thread_collector.append(tmp_thread)

    if len(thread_collector) >= max_thread_num:
        for a_thread in thread_collector:
            a_thread.join()
        thread_collector = []
for a_thread in thread_collector:
    a_thread.join()
# Out:
# 1198/1199

# %%
scores_ = {}
imgpaths_={}
for result in results:
    idx = int(os.path.basename(result['input_path'])[:-4])
    score = result["score"]
    scores_[idx] = score
    imgpaths_[idx]=result['input_path']
scores = []
imgpaths=[]
for k in sorted(scores_.keys()):
    scores.append(scores_[k])
    imgpaths.append(imgpaths_[k])
assert len(scores) == len(imgpaths)
plt.plot(scores)

# %%
ok_threshold = 1
V = 5
ok_thresholds=np.array([1,1.2,1,1,2]).reshape((1,V))
n_images = len(imgpaths)
n_frags = n_images // V
n_pieces = 6
n_images // (n_pieces * V)
# Out:
# 39

# %%
def Gamma_correction(img):
    img_=img/255
    
    img_[:,:,0]=np.power(img_[:,:,0],0.53)
    img_[:,:,1]=np.power(img_[:,:,1],0.53)
    img_[:,:,2]=np.power(img_[:,:,2],0.51)
    result=img_*255
    result.astype(np.uint8)
    return result
os.makedirs(f"{args.output_dir}", exist_ok=True)
cnt = 0
left, right = 0, n_pieces * V
newcameramtx, roi = cv2.getOptimalNewCameraMatrix(mtx, dist, (W,H), 1, (W,H))
while right < n_images:
    s = scores[left:right]
    s = np.array(s).reshape(n_pieces, V)
    #ok_mask = s > ok_threshold
    ok_mask=s>np.repeat(ok_thresholds,n_pieces,0)
    piece_ok = ok_mask.all(axis=-1)
    select_idx = 0
    select_score = -1e8
    for piece_idx in range(n_pieces):
        if not piece_ok[piece_idx]:
            continue
        if s[piece_idx].mean() > select_score:
            select_score = s[piece_idx].mean()
            select_idx = piece_idx
    if select_score > 0:
        base = left + select_idx * V
        select_ids = [idx for idx in range(base, base+V)]
        for idx in select_ids:
            print(scores[idx])
            img = cv2.imread(imgpaths[idx])
            print(os.path.basename(imgpaths[idx]))
            undst = cv2.undistort(img, mtx, dist)
            result= mask_invalid_pixel(undst,roi)
            result=Gamma_correction(result)
            cv2.imwrite(f"{args.output_dir}/{cnt:03d}.png",result)
            print(f"write {args.output_dir}/{cnt:03d}.png")
            cnt += 1
    left += n_pieces * V
    right += n_pieces * V
# Out:
# 1.4123363026480533
# 1.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/000.png
# 1.558666144449105
# 2.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/001.png
# 5.504824365997022
# 3.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/002.png
# 14.783101606791671
# 4.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/003.png
# 3.9192007900183747
# 5.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/004.png
# 1.768481861074982
# 46.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/005.png
# 1.8309536195376666
# 47.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/006.png
# 5.576903425342666
# 48.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/007.png
# 15.214601166682678
# 49.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/008.png
# 3.6340227691379705
# 50.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/009.png
# 1.9547483033984017
# 61.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/010.png
# 1.8081080557033566
# 62.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/011.png
# 6.031078086989672
# 63.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/012.png
# 14.823482641376328
# 64.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/013.png
# 4.346489036618534
# 65.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/014.png
# 2.2952672422572182
# 116.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/015.png
# 2.487075237383268
# 117.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/016.png
# 6.8422766355817375
# 118.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/017.png
# 15.731362159503526
# 119.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/018.png
# 4.224960409264698
# 120.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/019.png
# 2.625258573762624
# 146.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/020.png
# 1.8449686596079828
# 147.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/021.png
# 8.558343316659675
# 148.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/022.png
# 17.616048644707416
# 149.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/023.png
# 5.239009130453272
# 150.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/024.png
# 2.4428220972252888
# 166.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/025.png
# 1.8943529416568783
# 167.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/026.png
# 9.018974139142795
# 168.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/027.png
# 18.23290375209159
# 169.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/028.png
# 5.208715068622729
# 170.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/029.png
# 2.1190879362435373
# 186.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/030.png
# 1.7759624860251393
# 187.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/031.png
# 5.667553984317314
# 188.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/032.png
# 15.568469204304094
# 189.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/033.png
# 4.061818833650709
# 190.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/034.png
# 1.818376564355049
# 221.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/035.png
# 1.5256489821261396
# 222.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/036.png
# 5.211758414326216
# 223.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/037.png
# 12.938124656168
# 224.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/038.png
# 3.242236436255821
# 225.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/039.png
# 1.9361275458559066
# 266.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/040.png
# 1.5940333093357595
# 267.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/041.png
# 5.158900676363457
# 268.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/042.png
# 14.02789482641467
# 269.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/043.png
# 3.7500181363364127
# 270.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/044.png
# 1.9049836496485313
# 271.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/045.png
# 1.6648889171936272
# 272.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/046.png
# 5.0924957804089725
# 273.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/047.png
# 11.056304082220645
# 274.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/048.png
# 3.1447493129567903
# 275.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/049.png
# 1.8907219631349723
# 316.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/050.png
# 1.6154491897806849
# 317.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/051.png
# 5.149320849145873
# 318.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/052.png
# 10.121372422269333
# 319.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/053.png
# 3.493203900290475
# 320.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/054.png
# 1.96722482904927
# 1046.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/055.png
# 1.512309147545589
# 1047.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/056.png
# 5.57603596958669
# 1048.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/057.png
# 13.236818209173158
# 1049.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/058.png
# 3.5394852466195075
# 1050.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/059.png
# 1.8753435605248445
# 1066.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/060.png
# 1.5847659634403173
# 1067.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/061.png
# 6.057010006132204
# 1068.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/062.png
# 15.674744922021343
# 1069.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/063.png
# 4.495096342328159
# 1070.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/064.png
# 2.1769825013581663
# 1101.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/065.png
# 1.5611068388547236
# 1102.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/066.png
# 6.19551255377379
# 1103.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/067.png
# 17.7199054120058
# 1104.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/068.png
# 4.581676496704124
# 1105.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/069.png
# 2.238837610699372
# 1136.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/070.png
# 1.7451947903996445
# 1137.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/071.png
# 7.8170809740329075
# 1138.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/072.png
# 16.424897994956165
# 1139.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/073.png
# 4.806166850979395
# 1140.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/074.png
# 2.6290522669763083
# 1161.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/075.png
# 1.6621616719796013
# 1162.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/076.png
# 6.336284778607293
# 1163.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/077.png
# 18.614553234895844
# 1164.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/078.png
# 4.310875716154496
# 1165.png
# write D:\project\ipad\data\object_with_ipadfrontcamera\20230507-14-38-34/selected/079.png
